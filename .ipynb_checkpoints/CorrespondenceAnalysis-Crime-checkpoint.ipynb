# %% [markdown]
# # CORRESPONDENCE ANALYSIS
# ## visualisation technique for categorical data
# ### CA is a visualisation technique that can be applied to categorical data for data exploration.
#     -Categorical features are harder to analyse and visualise than numerical ones.
#     -CA uses SVD (matrix decomposition) so seems similar to Principle Components Analysis (PCA).
#     - The main difference is(out of that is used for categorical variabless)that CA is rather an exploratory, visualization tool.

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import numpy as np
import itertools

from scipy.stats import chi2_contingency

import seaborn as sns; 
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

import geocoder

# %% [markdown]
# # Create Sample DataSet
# ### CA applied to the crime data I used for geo visualisation:
#     - I want to understand some towns crime profile.
#     - i.e which are closer to each other but not by frequncy but share of different crime types
# ### The data is the Jan-Apr 2020 open crime data for the whole UK

# %%
# crime aggregation - see in the Geo Crime Map how to create it
#crime = 'crime_agg.csv'
#crime_df = pd.read_csv(crime)
# police files folder
police_fold = 'C:\\Datasets\\Crime_UK_2020\\'

# %%
# list to read the data
pol_list = ['avon-and-somerset','bedfordshire','btp','cambridgeshire','cheshire','city-of-london',
'cleveland','cumbria','derbyshire','devon-and-cornwall','dorset','durham',
'dyfed-powys','essex','gloucestershire','gwent','hampshire','hertfordshire',
'humberside','kent','lancashire','leicestershire','lincolnshire','merseyside',
'metropolitan','norfolk','northamptonshire','northern-ireland','northumbria','north-wales',
'north-yorkshire','nottinghamshire','south-wales','south-yorkshire','staffordshire','suffolk',
'surrey','sussex','thames-valley','warwickshire','west-mercia','west-midlands',
'west-yorkshire','wiltshire']

# %%
# list of the police files
def crime_source(police, year, months,police_fold):
    '''
    Need to run only once.
    create the list of the needed police files
    run before: -
    run after: crime_merge
    input: 
    -police: list of the police files
    -year: which year
    -month: months
    '''
    crime_pth = []
    for p in police:
        for y in year:
            for m in months:
                crime_pth.append(police_fold+y+'-'+m+'-'+p+'-street.csv')
    return crime_pth

def crime_merge(crime_pth):
    '''
    Need to run only once.
    Merge all the needed police files
    run before: crime_source
    run after: crime_prep
    '''
    crime_all=pd.DataFrame(columns=['Crime ID','Month','Reported by','Falls within','Longitude',
                               'Latitude','Location','LSOA code','LSOA name','Crime type',
                               'Last outcome category','Context'])
    for i in range(len(crime_pth)):
#        print(i,crime_pth[i] )
        crime_all=crime_all.append(pd.read_csv(crime_pth[i]))
    return crime_all

def mapbox_crime(address,box_size):
    '''based on the address given by geocoder, and manually given box size, calculate the coordinates'''
    long1 = address.lng -box_size[0]
    long2 = address.lng+box_size[0]
    lat1 = address.lat -box_size[1]
    lat2 = address.lat+box_size[1]
    MapBox2 = (long1,long2,lat1,lat2)
    return MapBox2

def crime_loc(df5):
    '''
    needs to be run each time I want to display a new map
    before: need to give the usual things
    after: folium_map2
    input: the crime_prep function third output
    output: the filtered data which now can be displayed on the map
    '''
    print('Number of coordinates in the db:',df5.shape[0])
    df6 = df5[(df5.Longitude>=long1) & (df5.Longitude<=long2) & (df5.Latitude>=lat1) &
                   (df5.Latitude<=lat2)]
    print('Number of coordinates in the box:',df6.shape[0])
    return df6

# %%
# it takes for a while reading and mergeing
crime_pth = crime_source(police=pol_list, year=['2020'], months=['01','02','03','04'], police_fold=police_fold)
crime_all = crime_merge(crime_pth)

# %%
crime_all.sample(3)
# Out:
#                                                 Crime ID    Month  \
# 10924  6b40b8af6b625c8349297f7ea56b6c5253ef89631cb6c2...  2020-01
# 10617  e25b3c7ab70b36a4390d49f2137b8518da24c872d3c6c1...  2020-01
# 17225  ccca287736ae2080d3209be54e87ab3a19af477a03db04...  2020-04
#
#                           Reported by                    Falls within  \
# 10924         Lancashire Constabulary         Lancashire Constabulary
# 10617  Avon and Somerset Constabulary  Avon and Somerset Constabulary
# 17225           West Yorkshire Police           West Yorkshire Police
#
#        Longitude   Latitude                     Location  LSOA code  \
# 10924  -2.676161  53.763837      On or near Derby Square  E01025297
# 10617  -2.339729  51.506882  On or near Old Hundred Lane  E01014891
# 17225  -1.536111  53.752742   On or near Manor Farm Rise  E01032497
#
#                         LSOA name                    Crime type  \
# 10924                Preston 014C                       Robbery
# 10617  South Gloucestershire 024F                 Vehicle crime
# 17225                  Leeds 099E  Violence and sexual offences
#
#              Last outcome category  Context
# 10924  Unable to prosecute suspect      NaN
# 10617          Under investigation      NaN
# 17225          Under investigation      NaN

# %%
# cherry picked towns
addresses = ['Ashford, Surrey', 'Didcot', 'Basingstoke', 'Newbury', 'Bournemouth', 'York', 'High Wycombe',
             'Bristol', 'Coventry', 'Lynmouth']
# create a list of longitudes and lattitudes of the center of the picked towns
address = []
for i in range(len(addresses)):
    address.append(geocoder.osm(addresses[i]+', UK'))

print(address[0].lng, address[0].lat)
# Out:
# -0.4619837 51.4330238

# %%
# The box size is random, can be changed but seems a reasonable size containing most of the town
box_size = (0.12,0.1) # shape and size of the crime box (longitude and latitude)

#create a list of dataframes of crimes of the given town defined by center and the box

crime = []
for i in range(len(addresses)):
    MapBox2 = mapbox_crime(address=address[i],box_size=box_size)
    long1 = MapBox2[0]
    long2 = MapBox2[1]
    lat1 = MapBox2[2]
    lat2 = MapBox2[3]
    temp = crime_loc(crime_all)
    crime.append(temp)
# Out:
# Number of coordinates in the db: 2031540
# Number of coordinates in the box: 33326
# Number of coordinates in the db: 2031540
# Number of coordinates in the box: 2032
# Number of coordinates in the db: 2031540
# Number of coordinates in the box: 4410
# Number of coordinates in the db: 2031540
# Number of coordinates in the box: 1979
# Number of coordinates in the db: 2031540
# Number of coordinates in the box: 13916
# Number of coordinates in the db: 2031540
# Number of coordinates in the box: 6428
# Number of coordinates in the db: 2031540
# Number of coordinates in the box: 5103
# Number of coordinates in the db: 2031540
# Number of coordinates in the box: 24497
# Number of coordinates in the db: 2031540
# Number of coordinates in the box: 13485
# Number of coordinates in the db: 2031540
# Number of coordinates in the box: 25

# %%
# create the list of aggreagated columns: crime type go to index to be easier to join

c = []
for i in range(len(addresses)):
    ctemp = crime[i].groupby('Crime type').count()[['Month']]
    ctemp.columns = [addresses[i]]
    c.append(ctemp)
c[3] # example of Newbury
# Out:
#                               Newbury
# Crime type
# Anti-social behaviour             310
# Bicycle theft                      24
# Burglary                          116
# Criminal damage and arson         215
# Drugs                              84
# Other crime                        33
# Other theft                       141
# Possession of weapons              12
# Public order                       79
# Robbery                            12
# Shoplifting                       134
# Theft from the person              16
# Vehicle crime                     151
# Violence and sexual offences      652

# %%
ftable = c[0]
for i in range(len(addresses)-1):
    ftable = ftable.join(c[i+1])
ftable = ftable.fillna(0) # replace the missing values with 0 - it's sensible here as it means there was not such crime there 
ftable
# Out:
#                               Ashford, Surrey  Didcot  Basingstoke  Newbury  \
# Crime type
# Anti-social behaviour                    9750     280          748      310
# Bicycle theft                             304      42           20       24
# Burglary                                 1744     122          273      116
# Criminal damage and arson                2063     235          417      215
# Drugs                                    1503      83          131       84
# Other crime                               627      46           73       33
# Other theft                              2352     116          255      141
# Possession of weapons                     202      18           51       12
# Public order                             1815     111          405       79
# Robbery                                   368       8           48       12
# Shoplifting                              1070      62          179      134
# Theft from the person                     311      21           23       16
# Vehicle crime                            3302     127          162      151
# Violence and sexual offences             7915     761         1625      652
#
#                               Bournemouth  York  High Wycombe  Bristol  \
# Crime type
# Anti-social behaviour                4438  2432           707     5204
# Bicycle theft                         251   233            39      495
# Burglary                              675   243           278     1259
# Criminal damage and arson            1230   438           466     2134
# Drugs                                 210   154           188      490
# Other crime                            97    74            75      320
# Other theft                           861   310           420     1673
# Possession of weapons                  54    26            46      137
# Public order                          542   289           295     2578
# Robbery                               111    28            47      316
# Shoplifting                           696   424           221     1195
# Theft from the person                  91    40            77      247
# Vehicle crime                         915   223           522     1676
# Violence and sexual offences         3745  1514          1722     6773
#
#                               Coventry  Lynmouth
# Crime type
# Anti-social behaviour             2572       6.0
# Bicycle theft                      121       0.0
# Burglary                           929       1.0
# Criminal damage and arson          893       4.0
# Drugs                              231       0.0
# Other crime                        249       0.0
# Other theft                        813       7.0
# Possession of weapons              134       0.0
# Public order                       759       0.0
# Robbery                            237       0.0
# Shoplifting                        584       0.0
# Theft from the person               87       0.0
# Vehicle crime                     1379       2.0
# Violence and sexual offences      4497       5.0

# %%
np.sum(ftable).plot(kind = 'bar')
plt.show()

# %% [markdown]
# ## DATA PREPARATION IS OVER

# %% [markdown]
# ## from here correspondence analysis
# ### Very different volume of crime, but I am interested in the profile
# ### Question is that CA can show us which towns have similar crime profile. I.E. similar share of crime for different types

# %% [markdown]
# ### Calculate Chi-Squared Statistic

# %%
Crosstab = np.array(ftable).T  # np.sum will calculate by cities if df, but hence as an numpy array the total

grandTotal = np.sum(Crosstab)  #  total number of crimes

correspondenceMatrix = np.divide(Crosstab,grandTotal)

rowTotals = np.sum(correspondenceMatrix, axis=1)

columnTotals = np.sum(correspondenceMatrix, axis=0)

# %%
print(grandTotal)
# Out:
# 105201.0

# %%
correspondenceMatrix[2:3]
# Out:
# array([[0.0071102 , 0.00019011, 0.00259503, 0.00396384, 0.00124524,
#         0.00069391, 0.00242393, 0.00048479, 0.00384977, 0.00045627,
#         0.0017015 , 0.00021863, 0.00153991, 0.01544662]])

# %%
independenceModel = np.outer(rowTotals, columnTotals) # expected dist if independent for the khi square test

# %% [markdown]
# ### The greater is 𝜒2, the greater is the certainty that the cities crime profile is different.

# %%
chiSquaredStatistic = grandTotal*np.sum(np.square(correspondenceMatrix-independenceModel)/independenceModel)
print(chiSquaredStatistic)
# Out:
# 6092.383884438052

# %%
# Quick check - compare to scipy Chi-Squared test
statistic, prob, dof, ex = chi2_contingency(Crosstab)
print(statistic)
print(np.round(prob, decimals=3))
# Out:
# 6092.383884438052
# 0.0

# %% [markdown]
# # Calculating Chi-Squared Distances
# #### For the purposes of CA, the differences between the crime profiles of the cities are measured by $\chi^2$ -distances, which are weighted Euclidean distances between normalized rows.

# %%
# pre-calculate normalised rows
norm_correspondenceMatrix = np.divide(correspondenceMatrix,rowTotals[:, None])

# %%
print(correspondenceMatrix[:3,:5],'\n\n',norm_correspondenceMatrix[:3,:5])
# Out:
# [[0.09267973 0.00288971 0.01657779 0.01961008 0.01428694]
#  [0.00266157 0.00039924 0.00115968 0.00223382 0.00078897]
#  [0.0071102  0.00019011 0.00259503 0.00396384 0.00124524]]
#
#  [[0.29256436 0.00912201 0.05233151 0.06190362 0.04509992]
#  [0.13779528 0.02066929 0.06003937 0.11564961 0.04084646]
#  [0.16961451 0.00453515 0.06190476 0.09455782 0.02970522]]

# %%
chiSquaredDistances = np.zeros((correspondenceMatrix.shape[0],correspondenceMatrix.shape[0]))

norm_columnTotals = np.sum(norm_correspondenceMatrix, axis=0)
for row in range(correspondenceMatrix.shape[0]):
    chiSquaredDistances[row]=np.sqrt(np.sum(np.square(norm_correspondenceMatrix
                                                        -norm_correspondenceMatrix[row])/columnTotals, axis=1))

# %%
dfchiSquaredDistances = pd.DataFrame(data=np.round(chiSquaredDistances*100).astype(int), columns=addresses)

# %%
dfchiSquaredDistances
# Out:
#    Ashford, Surrey  Didcot  Basingstoke  Newbury  Bournemouth  York  \
# 0                0      49           48       42           30    44
# 1               49       0           27       24           49    65
# 2               48      27            0       33           47    63
# 3               42      24           33        0           41    58
# 4               30      49           47       41            0    27
# 5               44      65           63       58           27     0
# 6               39      26           32       21           47    67
# 7               36      38           30       36           35    48
# 8               34      35           32       31           38    59
# 9              100     107          110      101           98   113
#
#    High Wycombe  Bristol  Coventry  Lynmouth
# 0            39       36        34       100
# 1            26       38        35       107
# 2            32       30        32       110
# 3            21       36        31       101
# 4            47       35        38        98
# 5            67       48        59       113
# 6             0       34        24        99
# 7            34        0        31       104
# 8            24       31         0       106
# 9            99      104       106         0

# %% [markdown]
# # Calculating Row Scores
#
# #### CA provides a means of representing a table of $\chi^2$ -distances in a graphical form. This is where the similarity with the PCA analysis comes in. To calculate such representation we need to transform the distances to points in a Cartesian coordinate system. This is achieved by a singular value decomposition (SVD) of a matrix of standardised residuals:

# %% [markdown]
# #### We are after the row scores, which are coordinates of points in a high-dimensional space (10 dimensions in this case). These points are arranged so that the Euclidean distance between two points is equal to the $\chi^2$ -distance between the two rows to which they correspond.

# %%
standardizedResiduals = np.divide((correspondenceMatrix-independenceModel),np.sqrt(independenceModel))

# %%
u,s,vh = np.linalg.svd(standardizedResiduals, full_matrices=False)

# %%
deltaR = np.diag(np.divide(1.0,np.sqrt(rowTotals)))

# %%
rowScores=np.dot(np.dot(deltaR,u),np.diag(s))

# %%
dfFirstTwoComponents = pd.DataFrame(data=[l[0:2] for l in rowScores], columns=['X', 'Y'], index=addresses)

# %%
dfFirstTwoComponents
# Out:
#                         X         Y
# Ashford, Surrey  0.121465  0.138872
# Didcot          -0.248680 -0.004806
# Basingstoke     -0.259118 -0.073223
# Newbury         -0.165654  0.015747
# Bournemouth      0.149832 -0.104388
# York             0.310674 -0.237578
# High Wycombe    -0.233180  0.112540
# Bristol         -0.116623 -0.121202
# Coventry        -0.156368  0.077524
# Lynmouth         0.052155  0.106903

# %%
sns.set(rc={'figure.figsize':(15,10)})
ax = sns.scatterplot(data=dfFirstTwoComponents,x='X', y='Y', hue=addresses)
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.get_legend().set_visible(False)

for label in addresses:
    plt.annotate(label, 
                 (dfFirstTwoComponents.loc[label,:]['X'],
                  dfFirstTwoComponents.loc[label,:]['Y']),
                 horizontalalignment='center', verticalalignment='center',size=11)

# %% [markdown]
# ### York and High Wycombe seem the complete opposite

# %%
YHW = ftable[['York','High Wycombe']]
YHW
# Out:
#                               York  High Wycombe
# Crime type
# Anti-social behaviour         2432           707
# Bicycle theft                  233            39
# Burglary                       243           278
# Criminal damage and arson      438           466
# Drugs                          154           188
# Other crime                     74            75
# Other theft                    310           420
# Possession of weapons           26            46
# Public order                   289           295
# Robbery                         28            47
# Shoplifting                    424           221
# Theft from the person           40            77
# Vehicle crime                  223           522
# Violence and sexual offences  1514          1722

# %%
YHW_colsum = np.sum(ftable[['York','High Wycombe']])
YHW_colsum
# Out:
# York            6428
# High Wycombe    5103
# dtype: int64

# %%
df = np.divide(YHW,YHW_colsum[:, None].T)
df
# Out:
#                                   York  High Wycombe
# Crime type
# Anti-social behaviour         0.378345      0.138546
# Bicycle theft                 0.036248      0.007643
# Burglary                      0.037803      0.054478
# Criminal damage and arson     0.068139      0.091319
# Drugs                         0.023958      0.036841
# Other crime                   0.011512      0.014697
# Other theft                   0.048227      0.082305
# Possession of weapons         0.004045      0.009014
# Public order                  0.044960      0.057809
# Robbery                       0.004356      0.009210
# Shoplifting                   0.065961      0.043308
# Theft from the person         0.006223      0.015089
# Vehicle crime                 0.034692      0.102293
# Violence and sexual offences  0.235532      0.337449

# %%
df.T.plot.bar(stacked=True)

# %% [markdown]
# ### Seems really different

# %% [markdown]
# ### Coventry and High Wycombe seem close to each other

# %%
CHW = ftable[['Coventry','High Wycombe']]
CHW
# Out:
#                               Coventry  High Wycombe
# Crime type
# Anti-social behaviour             2572           707
# Bicycle theft                      121            39
# Burglary                           929           278
# Criminal damage and arson          893           466
# Drugs                              231           188
# Other crime                        249            75
# Other theft                        813           420
# Possession of weapons              134            46
# Public order                       759           295
# Robbery                            237            47
# Shoplifting                        584           221
# Theft from the person               87            77
# Vehicle crime                     1379           522
# Violence and sexual offences      4497          1722

# %%
CHW_colsum = np.sum(ftable[['Coventry','High Wycombe']])
CHW_colsum
# Out:
# Coventry        13485
# High Wycombe     5103
# dtype: int64

# %%
df = np.divide(CHW,CHW_colsum[:, None].T)#.reset_index()
#pd.melt(df, id_vars =['Name'], value_vars =['Course', 'Age']) 
#df2 = pd.melt(df, id_vars =['Crime type'],value_vars =['Coventry', 'High Wycombe'])
#df2 = df2.set_index('Crime type')
#df2.plot.bar(x = 'Crime type',stacked=True)
df
# Out:
#                               Coventry  High Wycombe
# Crime type
# Anti-social behaviour         0.190730      0.138546
# Bicycle theft                 0.008973      0.007643
# Burglary                      0.068891      0.054478
# Criminal damage and arson     0.066222      0.091319
# Drugs                         0.017130      0.036841
# Other crime                   0.018465      0.014697
# Other theft                   0.060289      0.082305
# Possession of weapons         0.009937      0.009014
# Public order                  0.056285      0.057809
# Robbery                       0.017575      0.009210
# Shoplifting                   0.043307      0.043308
# Theft from the person         0.006452      0.015089
# Vehicle crime                 0.102262      0.102293
# Violence and sexual offences  0.333482      0.337449

# %%
df.T.plot.bar(stacked=True)
#CHW.T.plot.bar(stacked=True)

# %% [markdown]
# ### seems really closer than the previous one

# %% [markdown]
# # APPENDIX
# ## DETAILS OF THE MATRIX MANIPULATION
# I show here the calculations to make it clear how CA works, and not avoid the understanding the whole process above

# %%
# ftable transformed to matrix and transposed for ready to multiplication
Crosstab = np.array(ftable).T
np.array(ftable).T
# Out:
# array([[9.750e+03, 3.040e+02, 1.744e+03, 2.063e+03, 1.503e+03, 6.270e+02,
#         2.352e+03, 2.020e+02, 1.815e+03, 3.680e+02, 1.070e+03, 3.110e+02,
#         3.302e+03, 7.915e+03],
#        [2.800e+02, 4.200e+01, 1.220e+02, 2.350e+02, 8.300e+01, 4.600e+01,
#         1.160e+02, 1.800e+01, 1.110e+02, 8.000e+00, 6.200e+01, 2.100e+01,
#         1.270e+02, 7.610e+02],
#        [7.480e+02, 2.000e+01, 2.730e+02, 4.170e+02, 1.310e+02, 7.300e+01,
#         2.550e+02, 5.100e+01, 4.050e+02, 4.800e+01, 1.790e+02, 2.300e+01,
#         1.620e+02, 1.625e+03],
#        [3.100e+02, 2.400e+01, 1.160e+02, 2.150e+02, 8.400e+01, 3.300e+01,
#         1.410e+02, 1.200e+01, 7.900e+01, 1.200e+01, 1.340e+02, 1.600e+01,
#         1.510e+02, 6.520e+02],
#        [4.438e+03, 2.510e+02, 6.750e+02, 1.230e+03, 2.100e+02, 9.700e+01,
#         8.610e+02, 5.400e+01, 5.420e+02, 1.110e+02, 6.960e+02, 9.100e+01,
#         9.150e+02, 3.745e+03],
#        [2.432e+03, 2.330e+02, 2.430e+02, 4.380e+02, 1.540e+02, 7.400e+01,
#         3.100e+02, 2.600e+01, 2.890e+02, 2.800e+01, 4.240e+02, 4.000e+01,
#         2.230e+02, 1.514e+03],
#        [7.070e+02, 3.900e+01, 2.780e+02, 4.660e+02, 1.880e+02, 7.500e+01,
#         4.200e+02, 4.600e+01, 2.950e+02, 4.700e+01, 2.210e+02, 7.700e+01,
#         5.220e+02, 1.722e+03],
#        [5.204e+03, 4.950e+02, 1.259e+03, 2.134e+03, 4.900e+02, 3.200e+02,
#         1.673e+03, 1.370e+02, 2.578e+03, 3.160e+02, 1.195e+03, 2.470e+02,
#         1.676e+03, 6.773e+03],
#        [2.572e+03, 1.210e+02, 9.290e+02, 8.930e+02, 2.310e+02, 2.490e+02,
#         8.130e+02, 1.340e+02, 7.590e+02, 2.370e+02, 5.840e+02, 8.700e+01,
#         1.379e+03, 4.497e+03],
#        [6.000e+00, 0.000e+00, 1.000e+00, 4.000e+00, 0.000e+00, 0.000e+00,
#         7.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         2.000e+00, 5.000e+00]])

# %%
## for the correspondace analysis we need to divide each element with the total
grandTotal = np.sum(Crosstab)  #  total number of crimes
correspondenceMatrix = np.divide(Crosstab,grandTotal)
correspondenceMatrix
# Out:
# array([[9.26797274e-02, 2.88970637e-03, 1.65777892e-02, 1.96100798e-02,
#         1.42869364e-02, 5.96001939e-03, 2.23572019e-02, 1.92013384e-03,
#         1.72526877e-02, 3.49806561e-03, 1.01710060e-02, 2.95624566e-03,
#         3.13875343e-02, 7.52369274e-02],
#        [2.66157166e-03, 3.99235749e-04, 1.15968479e-03, 2.23381907e-03,
#         7.88965884e-04, 4.37258201e-04, 1.10265112e-03, 1.71101035e-04,
#         1.05512305e-03, 7.60449045e-05, 5.89348010e-04, 1.99617874e-04,
#         1.20721286e-03, 7.23377154e-03],
#        [7.11019857e-03, 1.90112261e-04, 2.59503237e-03, 3.96384065e-03,
#         1.24523531e-03, 6.93909754e-04, 2.42393133e-03, 4.84786266e-04,
#         3.84977329e-03, 4.56269427e-04, 1.70150474e-03, 2.18629100e-04,
#         1.53990932e-03, 1.54466212e-02],
#        [2.94674005e-03, 2.28134714e-04, 1.10265112e-03, 2.04370681e-03,
#         7.98471497e-04, 3.13685231e-04, 1.34029144e-03, 1.14067357e-04,
#         7.50943432e-04, 1.14067357e-04, 1.27375215e-03, 1.52089809e-04,
#         1.43534757e-03, 6.19765972e-03],
#        [4.21859108e-02, 2.38590888e-03, 6.41628882e-03, 1.16919041e-02,
#         1.99617874e-03, 9.22044467e-04, 8.18433285e-03, 5.13303105e-04,
#         5.15204228e-03, 1.05512305e-03, 6.61590669e-03, 8.65010789e-04,
#         8.69763595e-03, 3.55985209e-02],
#        [2.31176510e-02, 2.21480784e-03, 2.30986397e-03, 4.16345852e-03,
#         1.46386441e-03, 7.03415367e-04, 2.94674005e-03, 2.47145940e-04,
#         2.74712218e-03, 2.66157166e-04, 4.03037994e-03, 3.80224523e-04,
#         2.11975171e-03, 1.43914982e-02],
#        [6.72046844e-03, 3.70718910e-04, 2.64256043e-03, 4.42961569e-03,
#         1.78705526e-03, 7.12920980e-04, 3.99235749e-03, 4.37258201e-04,
#         2.80415585e-03, 4.46763814e-04, 2.10074049e-03, 7.31932206e-04,
#         4.96193002e-03, 1.63686657e-02],
#        [4.94672104e-02, 4.70527847e-03, 1.19675668e-02, 2.02849783e-02,
#         4.65775040e-03, 3.04179618e-03, 1.59028907e-02, 1.30226899e-03,
#         2.45054705e-02, 3.00377373e-03, 1.13592076e-02, 2.34788643e-03,
#         1.59314075e-02, 6.43815173e-02],
#        [2.44484368e-02, 1.15017918e-03, 8.83071454e-03, 8.48851247e-03,
#         2.19579662e-03, 2.36689765e-03, 7.72806342e-03, 1.27375215e-03,
#         7.21476032e-03, 2.25283030e-03, 5.55127803e-03, 8.26988337e-04,
#         1.31082404e-02, 4.27467420e-02],
#        [5.70336784e-05, 0.00000000e+00, 9.50561306e-06, 3.80224523e-05,
#         0.00000000e+00, 0.00000000e+00, 6.65392915e-05, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.90112261e-05, 4.75280653e-05]])

# %%
rowTotals = np.sum(correspondenceMatrix, axis=1) # Towns total (columns in the not transposed one)
columnTotals = np.sum(correspondenceMatrix, axis=0) # crime types total (row in the not transposed one)
print(rowTotals,'\n\n',columnTotals)
# Out:
# [3.16784061e-01 1.93154057e-02 4.19197536e-02 1.88116083e-02
#  1.32280111e-01 6.11020808e-02 4.85071435e-02 2.32859003e-01
#  1.28183192e-01 2.37640327e-04]
#
#  [0.25139495 0.01453408 0.05361166 0.07694794 0.02922025 0.01515195
#  0.066045   0.00646382 0.06533208 0.0111691  0.04339312 0.00867862
#  0.08040798 0.27764945]

# %% [markdown]
# #### independenceModel is the theoratical matrix based on the marginal distribution. What if the two axes were independent, We get it by multiplying the appropriate marginal probabilities

# %%
independenceModel = np.outer(rowTotals, columnTotals) # 2 vectors outher multiplication > gives a matrix
print(independenceModel.shape,'\n\n',independenceModel) # rows towns, columns crime types
# Out:
# (10, 14)
#
#  [[7.96379128e-02 4.60416564e-03 1.69833186e-02 2.43758802e-02
#   9.25651090e-03 4.79989537e-03 2.09220032e-02 2.04763416e-03
#   2.06961612e-02 3.53819138e-03 1.37462499e-02 2.74924999e-03
#   2.54719667e-02 8.79549209e-02]
#  [4.85579544e-03 2.80731698e-04 1.03553092e-03 1.48628064e-03
#   5.64401073e-04 2.92666009e-04 1.27568596e-03 1.24851246e-04
#   1.26191561e-03 2.15735609e-04 8.38155790e-04 1.67631158e-04
#   1.55311278e-03 5.36291182e-03]
#  [1.05384143e-02 6.09265152e-04 2.24738748e-03 3.22563859e-03
#   1.22490587e-03 6.35165894e-04 2.76859011e-03 2.70961611e-04
#   2.73870464e-03 4.68205725e-04 1.81902905e-03 3.63805810e-04
#   3.37068275e-03 1.16389966e-02]
#  [4.72914329e-03 2.73409464e-04 1.00852150e-03 1.44751446e-03
#   5.49679982e-04 2.85032495e-04 1.24241266e-03 1.21594791e-04
#   1.22900147e-03 2.10108646e-04 8.16294443e-04 1.63258889e-04
#   1.51260344e-03 5.22303272e-03]
#  [3.32545518e-02 1.92257004e-03 7.09175605e-03 1.01786818e-02
#   3.86525853e-03 2.00430127e-03 8.73643990e-03 8.55034418e-04
#   8.64213463e-03 1.47744918e-03 5.74004723e-03 1.14800945e-03
#   1.06363767e-02 3.67275004e-02]
#  [1.53607545e-02 8.88062675e-04 3.27578384e-03 4.70167911e-03
#   1.78541835e-03 9.25815503e-04 4.03548690e-03 3.94952661e-04
#   3.99192594e-03 6.82454966e-04 2.65141015e-03 5.30282029e-04
#   4.91309494e-03 1.69649592e-02]
#  [1.21944508e-02 7.05006819e-04 2.60054837e-03 3.73252466e-03
#   1.41739108e-03 7.34977678e-04 3.20365427e-03 3.13541293e-04
#   3.16907251e-03 5.41780911e-04 2.10487647e-03 4.20975295e-04
#   3.90036147e-03 1.34679818e-02]
#  [5.85395772e-02 3.38439194e-03 1.24839572e-02 1.79180201e-02
#   6.80419935e-03 3.52826733e-03 1.53791728e-02 1.50515796e-03
#   1.52131627e-02 2.60082441e-03 1.01044795e-02 2.02089590e-03
#   1.87237223e-02 6.46531746e-02]
#  [3.22246070e-02 1.86302507e-03 6.87211342e-03 9.86343229e-03
#   3.74554551e-03 1.94222496e-03 8.46585887e-03 8.28552682e-04
#   8.37447439e-03 1.43169030e-03 5.56226911e-03 1.11245382e-03
#   1.03069517e-02 3.55899931e-02]
#  [5.97415777e-05 3.45388408e-06 1.27402918e-05 1.82859331e-05
#   6.94391084e-06 3.60071369e-06 1.56949553e-05 1.53606356e-06
#   1.55255365e-05 2.65422747e-06 1.03119561e-05 2.06239121e-06
#   1.91081788e-05 6.59807065e-05]]

# %% [markdown]
# #### chi square stats: difference of the 2 matrices, elementwise square, divided by the independent probability and summarise. Multiplied by the grand total to have the right value.

# %%
chiSquaredStatistic = grandTotal*np.sum(np.square(correspondenceMatrix-independenceModel)/independenceModel)
print(chiSquaredStatistic)
# Out:
# 6092.383884438052

# %%
# Quick check - compare to scipy Chi-Squared test using the original Crosstab -  no need the grand total
statistic, prob, dof, ex = chi2_contingency(Crosstab) # this function is from scipy - see the very beginning
print(statistic) # chi2 valie
print(np.round(prob, decimals=3),dof) # p value and degree of freedom (13*9)
# ex is the expected frequencies, based on the marginal sums of the table - dont need it
# Out:
# 6092.383884438052
# 0.0 117

# %%
# pre-calculate normalised rows - divided by town totals of the corrresp matrix
norm_correspondenceMatrix = np.divide(correspondenceMatrix,rowTotals[:, None])

# %%
chiSquaredDistances = np.zeros((correspondenceMatrix.shape[0],correspondenceMatrix.shape[0])) # 10*10 matrix fukll of zeros

norm_columnTotals = np.sum(norm_correspondenceMatrix, axis=0) # columns total of the corr matrix. Crimetypes
for row in range(correspondenceMatrix.shape[0]):
    chiSquaredDistances[row]=np.sqrt(np.sum(np.square(norm_correspondenceMatrix
                                                        -norm_correspondenceMatrix[row])/columnTotals, axis=1))
# e.g first row: we nullify the first row, square of the matrix, divided by the columns total, summarise by the axis=1 and square root

# %%
# this is the first row:
np.sqrt(np.sum(np.square(norm_correspondenceMatrix-norm_correspondenceMatrix[0])/columnTotals, axis=1))
# Out:
# array([0.        , 0.48743955, 0.47735361, 0.41897571, 0.29967997,
#        0.44253163, 0.39498704, 0.35990665, 0.34400466, 1.00351311])

# %%
dfchiSquaredDistances = pd.DataFrame(data=np.round(chiSquaredDistances*100).astype(int), columns=addresses)
dfchiSquaredDistances
# Out:
#    Ashford, Surrey  Didcot  Basingstoke  Newbury  Bournemouth  York  \
# 0                0      49           48       42           30    44
# 1               49       0           27       24           49    65
# 2               48      27            0       33           47    63
# 3               42      24           33        0           41    58
# 4               30      49           47       41            0    27
# 5               44      65           63       58           27     0
# 6               39      26           32       21           47    67
# 7               36      38           30       36           35    48
# 8               34      35           32       31           38    59
# 9              100     107          110      101           98   113
#
#    High Wycombe  Bristol  Coventry  Lynmouth
# 0            39       36        34       100
# 1            26       38        35       107
# 2            32       30        32       110
# 3            21       36        31       101
# 4            47       35        38        98
# 5            67       48        59       113
# 6             0       34        24        99
# 7            34        0        31       104
# 8            24       31         0       106
# 9            99      104       106         0
